# %%
import pandas as pd
import requests

# %% [markdown]
# # Extração tabela bancos

# %%
url = "https://brasilapi.com.br/api/banks/v1"
response = requests.get(url)

# %%
if response.status_code == 200:
    data_json = response.json()
    from plyer import notification 
    notification.notify(
     title='SUCESSO',
     message='Base carregada com sucesso',
     app_name='API',
     timeout=10 )
else:
    from plyer import notification 
    notification.notify(
     title='ERRO',
     message='Erro ao carregar base de dados',
     app_name='API',
     timeout=10 )

# %%
bancos  = pd.DataFrame(data_json)
bancos.head(10)
# Out:
#        ispb                             name   code  \
# 0  00000000               BCO DO BRASIL S.A.    1.0
# 1  00000208       BRB - BCO DE BRASILIA S.A.   70.0
# 2  00038121                            Selic    NaN
# 3  00038166                            Bacen    NaN
# 4  00122327            SANTINVEST S.A. - CFI  539.0
# 5  00204963                        CCR SEARA  430.0
# 6  00250699                      AGK CC S.A.  272.0
# 7  00315557   CONF NAC COOP CENTRAIS UNICRED  136.0
# 8  00329598  ÍNDIGO INVESTIMENTOS DTVM LTDA.  407.0
# 9  00360305          CAIXA ECONOMICA FEDERAL  104.0
#
#                                             fullName
# 0                               Banco do Brasil S.A.
# 1                       BRB - BANCO DE BRASILIA S.A.
# 2                    Banco Central do Brasil - Selic
# 3                            Banco Central do Brasil
# 4  SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# 5    COOPERATIVA DE CREDITO RURAL SEARA - CREDISEARA
# ...

# %%
bancos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ispb      359 non-null    object
#  1   name      357 non-null    object
#  2   code      348 non-null    float64
#  3   fullName  357 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 11.3+ KB

# %% [markdown]
# # Extração tabela Pix

# %%
url1 = "https://brasilapi.com.br/api/pix/v1/participants/"
response = requests.get(url1)

# %%
if response.status_code == 200:
    pix1 = response.json()
    from plyer import notification 
    notification.notify(
     title='SUCESSO',
     message='Base carregada com sucesso',
     app_name='API',
     timeout=10 )
else:
    from plyer import notification 
    notification.notify(
     title='ERRO',
     message='Erro ao carregar API',
     app_name='API',
     timeout=10 )

# %%
pix = pd.DataFrame(pix1)
pix.head(10)
# Out:
#        ispb                                               nome  \
# 0  00000000                               BANCO DO BRASIL S.A.
# 1  00000208                       BRB - BANCO DE BRASILIA S.A.
# 2  00068987  COOPERATIVA DE CRÉDITO ARACREDI LTDA. - SICOOB...
# 3  00075847  COOPERATIVA DE CRÉDITO UNICRED CENTRO-SUL LTDA...
# 4  00106180  CENTRAL DAS COOPERATIVAS DE CRÉDITO DOS ESTADO...
# 5  00204963    COOPERATIVA DE CREDITO RURAL SEARA - CREDISEARA
# 6  00259231  SICOOB UNIMAIS METROPOLITANA - COOPERATIVA DE ...
# 7  00309024  CENTRAL DAS COOPERATIVAS DE ECONOMIA E CREDITO...
# 8  00315557  CONFEDERAÇÃO NACIONAL DAS COOPERATIVAS CENTRAI...
# 9  00329598  SEFER INVESTIMENTOS DISTRIBUIDORA DE TÍTULOS E...
#
#                                      nome_reduzido modalidade_participacao  \
# 0                               BCO DO BRASIL S.A.                    PDCT
# 1                       BRB - BCO DE BRASILIA S.A.                    PDCT
# ...

# %%
pix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835 entries, 0 to 834
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ispb                     835 non-null    object
#  1   nome                     835 non-null    object
#  2   nome_reduzido            835 non-null    object
#  3   modalidade_participacao  835 non-null    object
#  4   tipo_participacao        835 non-null    object
#  5   inicio_operacao          835 non-null    object
# dtypes: object(6)
# memory usage: 39.3+ KB

# %% [markdown]
# # Extração Tabela corretoras

# %%
url2 = "https://brasilapi.com.br/api/cvm/corretoras/v1"
response = requests.get(url2)

# %%
if response.status_code == 200:
    corretoras = response.json()
    from plyer import notification 
    notification.notify(
     title='SUCESSO',
     message='Base carregada com sucesso',
     app_name='API',
     timeout=10 )
else:
    from plyer import notification 
    notification.notify(
     title='ERRO',
     message='Erro ao carregar API',
     app_name='API',
     timeout=10 )

# %%
corretoras1 = pd.DataFrame(corretoras)
corretoras1.head(10)
# Out:
#              cnpj        type  \
# 0  76621457000185  CORRETORAS
# 1  33817677000176  CORRETORAS
# 2  10664027000132  CORRETORAS
# 3  44527444000155  CORRETORAS
# 4  33819590000138  CORRETORAS
# 5  92856905000186  CORRETORAS
# 6  24159923000159  CORRETORAS
# 7  43050917000103  CORRETORAS
# 8  09259391000138  CORRETORAS
# 9  35937283000187  CORRETORAS
#
#                                          nome_social  \
# 0                                      4UM DTVM S.A.
# 1  ABC BRASIL DISTRIBUIDORA DE TÍTULOS E VALORES ...
# 2                                 ABERTURA CCVM LTDA
# 3  ABN AMRO CLEARING CORRETORA DE T-TULOS E VALOR...
# 4            AÇÃO S.A. CORRETORA DE VALORES E CÂMBIO
# 5                                   ACTION CCVM S.A.
# 6        ACTION S.A. EMPREENDIMENTOS E PARTICIPAÇÕES
# 7  ACTIVTRADES CORRETORA DE CÂMBIO, TÍTULOS E VAL...
# 8                       ADEMAR WANDERLEY - CCVM LTDA
# 9  ADOLPHO OLIVEIRA & ASSOCIADOS CORRETORA DE VAL...
#
# ...

# %%
corretoras1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cnpj                      374 non-null    object
#  1   type                      374 non-null    object
#  2   nome_social               374 non-null    object
#  3   nome_comercial            374 non-null    object
#  4   status                    374 non-null    object
#  5   email                     374 non-null    object
#  6   telefone                  374 non-null    object
#  7   cep                       374 non-null    object
#  8   pais                      374 non-null    object
#  9   uf                        374 non-null    object
#  10  municipio                 374 non-null    object
#  11  bairro                    374 non-null    object
#  12  complemento               374 non-null    object
# ...
