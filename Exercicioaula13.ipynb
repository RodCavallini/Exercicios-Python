# %%
import pandas as pd

# %%
df = pd.read_csv('realtor-data.csv')
df.head()
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0

# %%
df.shape
# Out:
# (100000, 10)

# %%
forsale = df.loc[df['status'] == 'for_sale']
forsale
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price
# ...

# %%
df.value_counts('status')
# Out:
# status
# for_sale          99819
# ready_to_build      181
# Name: count, dtype: int64

# %%
massa = forsale.loc[forsale['state'] == 'Massachusetts']
massa = massa.sort_values('house_size',ascending=False)
massa = massa.drop_duplicates(subset=['status','city','state','price'],keep='last')
massa = massa.sample(n = 250 , random_state=1)
massa
# Out:
#          status   bed  bath  acre_lot              city          state  \
# 46416  for_sale   2.0   2.0       NaN       Easthampton  Massachusetts
# 95507  for_sale   3.0   2.0      0.16        Framingham  Massachusetts
# 62591  for_sale   4.0   6.0     44.00  West Stockbridge  Massachusetts
# 79581  for_sale   2.0   3.0       NaN        Boxborough  Massachusetts
# 74356  for_sale   NaN   NaN      1.20            Ludlow  Massachusetts
# ...         ...   ...   ...       ...               ...            ...
# 93581  for_sale   NaN   NaN      3.86            Palmer  Massachusetts
# 73548  for_sale  11.0   6.0      0.09         Fitchburg  Massachusetts
# 80101  for_sale   4.0   2.0      0.24            Woburn  Massachusetts
# 98889  for_sale   3.0   3.0      2.09           Douglas  Massachusetts
# 64278  for_sale   NaN   NaN     43.00   New Marlborough  Massachusetts
#
#        zip_code  house_size prev_sold_date      price
# 46416    1027.0      1576.0            NaN   499900.0
# ...

# %%
puerto = forsale.loc[forsale['state'] == 'Puerto Rico']
puerto = puerto.sort_values('house_size',ascending=False)
puerto = puerto.drop_duplicates(subset=['status','city','state','price'],keep='last')
puerto = puerto.sample(n = 250 , random_state=1)
puerto
# Out:
#          status  bed  bath  acre_lot        city        state  zip_code  \
# 4826   for_sale  2.0   2.0    102.07       Ponce  Puerto Rico     717.0
# 21608  for_sale  3.0   1.0      0.04    San Juan  Puerto Rico     915.0
# 20654  for_sale  5.0   2.0      0.37     Bayamon  Puerto Rico     956.0
# 296    for_sale  3.0   2.0      0.21       Camuy  Puerto Rico     627.0
# 2596   for_sale  6.0   4.0      0.37     Hatillo  Puerto Rico     659.0
# ...         ...  ...   ...       ...         ...          ...       ...
# 5481   for_sale  5.0   3.0      0.03    Aibonito  Puerto Rico     705.0
# 10603  for_sale  4.0   3.0       NaN     Humacao  Puerto Rico     791.0
# 2586   for_sale  3.0   1.0     10.76     Florida  Puerto Rico     650.0
# 8876   for_sale  2.0   2.0       NaN  Rio Grande  Puerto Rico     745.0
# 8137   for_sale  3.0   3.0       NaN      Rincon  Puerto Rico     677.0
#
#        house_size prev_sold_date     price
# 4826          NaN            NaN  150000.0
# ...

# %%
conne = forsale.loc[forsale['state'] == 'Connecticut']
conne = conne.sort_values('house_size',ascending=False)
conne = conne.drop_duplicates(subset=['status','city','state','price'],keep='last')
conne = conne.sample(n = 250 , random_state=1)
conne
# Out:
#          status  bed  bath  acre_lot           city        state  zip_code  \
# 48834  for_sale  3.0   2.0      0.56  South Windsor  Connecticut    6074.0
# 84924  for_sale  3.0   3.0      1.10       Thompson  Connecticut    6277.0
# 49794  for_sale  4.0   3.0      1.40    East Granby  Connecticut    6026.0
# 57229  for_sale  4.0   1.0     43.85      Bethlehem  Connecticut    6751.0
# 56803  for_sale  4.0   5.0     16.06       Woodbury  Connecticut    6798.0
# ...         ...  ...   ...       ...            ...          ...       ...
# 32789  for_sale  2.0   1.0      2.48    Marlborough  Connecticut    6447.0
# 60435  for_sale  3.0   3.0      1.82     Colchester  Connecticut    6415.0
# 57524  for_sale  3.0   2.0      0.58      Watertown  Connecticut    6795.0
# 60265  for_sale  3.0   2.0      0.20     Rocky Hill  Connecticut    6067.0
# 32211  for_sale  4.0   3.0      0.34         Vernon  Connecticut    6066.0
#
#        house_size prev_sold_date      price
# ...

# %%
rhodeyork = forsale.loc[forsale['state'].isin(['Rhode Island','New York'])]
rhodeyork = rhodeyork.sort_values('house_size',ascending=False)
rhodeyork = rhodeyork.drop_duplicates(subset=['status','city','state','price'],keep='last')
rhodeyork = rhodeyork.sample(n = 250 , random_state=1)
rhodeyork
# Out:
#          status  bed  bath  acre_lot              city         state  \
# 95431  for_sale  3.0   2.0      0.21           Warwick  Rhode Island
# 93840  for_sale  7.0   3.0      0.09        Providence  Rhode Island
# 94690  for_sale  2.0   2.0      0.96          Scituate  Rhode Island
# 96481  for_sale  2.0   2.0       NaN           Lincoln  Rhode Island
# 64635  for_sale  3.0   1.0      2.30       Pine Plains      New York
# ...         ...  ...   ...       ...               ...           ...
# 95922  for_sale  3.0   2.0      0.30  North Providence  Rhode Island
# 96206  for_sale  3.0   2.0      0.12        Barrington  Rhode Island
# 64263  for_sale  NaN   NaN    103.00             Dover      New York
# 64646  for_sale  4.0   4.0      4.27        Elizaville      New York
# 92587  for_sale  2.0   1.0       NaN        Woonsocket  Rhode Island
#
#        zip_code  house_size prev_sold_date     price
# 95431    2888.0      1334.0            NaN  339900.0
# ...

# %%
juncao = pd.concat([massa,puerto,conne,rhodeyork])
juncao
# Out:
#          status  bed  bath  acre_lot              city          state  \
# 46416  for_sale  2.0   2.0       NaN       Easthampton  Massachusetts
# 95507  for_sale  3.0   2.0      0.16        Framingham  Massachusetts
# 62591  for_sale  4.0   6.0     44.00  West Stockbridge  Massachusetts
# 79581  for_sale  2.0   3.0       NaN        Boxborough  Massachusetts
# 74356  for_sale  NaN   NaN      1.20            Ludlow  Massachusetts
# ...         ...  ...   ...       ...               ...            ...
# 95922  for_sale  3.0   2.0      0.30  North Providence   Rhode Island
# 96206  for_sale  3.0   2.0      0.12        Barrington   Rhode Island
# 64263  for_sale  NaN   NaN    103.00             Dover       New York
# 64646  for_sale  4.0   4.0      4.27        Elizaville       New York
# 92587  for_sale  2.0   1.0       NaN        Woonsocket   Rhode Island
#
#        zip_code  house_size prev_sold_date      price
# 46416    1027.0      1576.0            NaN   499900.0
# ...

# %%
juncao.to_excel('Amostra.xlsx' , index=False)
