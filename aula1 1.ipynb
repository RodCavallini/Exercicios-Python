# %%
import pandas as pd
import numpy as np

# %%
# !Pip install matplotlib
# Out:
# ^C
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.9 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.9 kB 262.6 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/165.9 kB 281.8 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/165.9 kB 595.3 kB/s eta 0:00:01
#      ------------------------------------ 165.9/165.9 kB 766.9 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\rodri\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rodri\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rodri\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    --------- ------------------------------ 1.9/7.8 MB 40.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.3/7.8 MB 45.8 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 31.3 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    --------------------------------------- 189.9/189.9 kB 11.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------  2.2/2.2 MB 69.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 35.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 2.9 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------------- ------------------- 1.3/2.6 MB 27.9 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 23.1 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 23.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 14.8 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.2
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 8, 6, 4, 2]

plt.plot(x, y)

plt.show()

# %%
x = ['A', 'B', 'C', 'D', 'E']
y = [3, 7, 1, 8, 4]
#plt.bar(x, y)
#plt.show()
fig,ax = plt.subplots()
ax.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ['Maçãs', 'Bananas', 'Laranjas', 'Morangos']
quantidades = [20, 25, 10, 30]
plt.pie(quantidades, labels=labels)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 8, 6, 4, 2]
plt.scatter(x, y)
plt.show()

# %%
dados = [1, 3, 3, 4, 4, 4, 5, 5, 6, 7, 8, 9]
plt.hist(dados, bins=4)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.fill_between(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 8, 6, 4, 2]

plt.plot(x, y)

# Definindo o título e etiquetas dos eixos
plt.title("Gráfico de dispersão")
plt.xlabel("Eixo x")
plt.ylabel("Eixo y")

plt.show()

# %%
# Dados para o gráfico de linha
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Configurações do gráfico
plt.plot(x, y, 
         color='blue', 
         linestyle='--', 
         linewidth=2, 
         marker='o', 
         markersize=8, 
         markerfacecolor='white')
plt.title('Título do gráfico')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.xlim(0, 6)
plt.ylim(0, 12)
plt.grid(True)

plt.show()

# %%
# Dados para os gráficos de linha
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

# Criação de subplots de linhas
fig, axs = plt.subplots(3, 1, figsize=(8, 10))
axs[0].plot(x, y1)
axs[0].set_title('Gráfico de Seno')
axs[1].plot(x, y2)
axs[1].set_title('Gráfico de Cosseno')
axs[2].plot(x, y3)
axs[2].set_title('Gráfico de Tangente')

plt.show()

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rodri\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rodri\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rodri\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\rodri\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    --------------------------------------- 294.9/294.9 kB 17.8 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

x = np.random.normal(size=100)

# Plotar histograma e distribuição
sns.displot(x, kde=True )
plt.show()

# %%
data = {'peso': [80, 65, 70, 60, 75, 66, 61, 73, 77],
        'altura': [180, 170, 175, 167, 172, 169, 166, 178, 169]}
df = pd.DataFrame(data)

# Plotar scatter plot
sns.scatterplot(x='peso', y='altura', data=df)
plt.show()

# %%
data = {'tipo': ['Venda', 'Venda', 'Compra', 'Compra', 'Venda', 'Compra'],
        'valor': [1000, 1500, 500, 800, 1200, 600]}

df = pd.DataFrame(data)

sns.boxplot(x='tipo', y='valor', data=df)
plt.show()
